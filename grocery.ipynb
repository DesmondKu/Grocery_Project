# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
from pandas_profiling import ProfileReport
import sklearn

# %%
#load dataset
dataset_folder = r"G:\My Drive\Desmond\DS_Project\1_Github\Grocery_Project"

# %%
df_main = pd.read_csv(dataset_folder + "\Australia_Grocery_2022Sep.csv")

# %%
df_main
# Out:
#          index  Postal_code        Category   Sub_category  \
# 0            0         2044  Meat & seafood        Poultry
# 1            1         2044  Meat & seafood        Poultry
# 2            2         2044  Meat & seafood        Poultry
# 3            3         2044  Meat & seafood        Poultry
# 4            4         2044  Meat & seafood        Poultry
# ...        ...          ...             ...            ...
# 488635  488635         9601          Drinks  Coffee Drinks
# 488636  488636         9601          Drinks  Coffee Drinks
# 488637  488637         9601          Drinks  Coffee Drinks
# 488638  488638         9601          Drinks  Coffee Drinks
# 488639  488639         9601          Drinks  Coffee Drinks
#
#              Product_Group                                       Product_Name  \
# 0            Chicken offal                       RSPCA Approved Chicken Necks
# 1            Chicken offal                      RSPCA Approved Chicken Livers
# 2            Chicken offal                     RSPCA Approved Chicken Giblets
# 3            Chicken offal                      RSPCA Approved Chicken Frames
# 4          Crumbed chicken                RSPCA Chicken Schnitzel Plain Crumb
# ...                    ...                                                ...
# 488635  Accessories Coffee                            Coffee Machine Descaler
# 488636  Accessories Coffee  Coffee Mate French Vanilla Flavoured Liquid Co...
# 488637  Accessories Coffee              Coffee Filter Papers 10-12 Cup Size 4
# 488638  Accessories Coffee                             Barista Coffee Machine
# 488639  Accessories Coffee           Qualita ORO Mountain Grown Ground Coffee
#
#         Package_price   Price_per_unit       package_size  is_estimated  ...  \
# 0                7.15    $6.50 per 1Kg      approx. 1.1kg             1  ...
# 1                5.40    $9.00 per 1Kg       approx. 600g             1  ...
# 2                4.50    $7.50 per 1Kg       approx. 600g             1  ...
# 3                3.38    $4.50 per 1Kg  approx. 750g each             1  ...
# 4               10.50    $8.75 per 1Kg              1.2kg             0  ...
# ...               ...              ...                ...           ...  ...
# 488635           4.00  $1.60 per 100mL              250mL             0  ...
# 488636           5.00  $3.33 per 100mL              150mL             0  ...
# 488637           3.00    $0.08 per 1Ea             1 pack             0  ...
# 488638          99.00   $99.00 per 1Ea             1 each             0  ...
# 488639          17.00   $3.40 per 100G               500g             0  ...
#
#         Retail_price                                        Product_Url  \
# 0                NaN  https://shop.coles.com.au/a/alexandria/product...
# 1                NaN  https://shop.coles.com.au/a/alexandria/product...
# 2                NaN  https://shop.coles.com.au/a/alexandria/product...
# 3               4.13  https://shop.coles.com.au/a/alexandria/product...
# 4              11.00  https://shop.coles.com.au/a/alexandria/product...
# ...              ...                                                ...
# 488635           NaN  https://shop.coles.com.au/a/canberra-civic/pro...
# 488636           NaN  https://shop.coles.com.au/a/canberra-civic/pro...
# 488637           NaN  https://shop.coles.com.au/a/canberra-civic/pro...
# 488638           NaN  https://shop.coles.com.au/a/canberra-civic/pro...
# 488639           NaN  https://shop.coles.com.au/a/canberra-civic/pro...
#
#           Brand       Sku              RunDate unit_price unit_price_unit  \
# 0         Coles  1491280P  2022-11-09 08:23:06       6.50             1Kg
# 1         Coles  1718058P  2022-11-09 08:23:06       9.00             1Kg
# 2         Coles  2565429P  2022-11-09 08:23:06       7.50             1Kg
# 3         Coles  3199541P  2022-11-09 08:23:06       4.50             1Kg
# 4         Coles  2904193P  2022-11-09 08:23:06       8.75             1Kg
# ...         ...       ...                  ...        ...             ...
# 488635    Coles  3209077P  2022-11-09 08:23:06       1.60           100mL
# 488636   Nestle  8987047P  2022-11-09 08:23:06       3.33           100mL
# 488637   Harris    47955P  2022-11-09 08:23:06       0.08             1Ea
# 488638     L'OR  5745722P  2022-11-09 08:23:06      99.00             1Ea
# 488639  Lavazza  3515222P  2022-11-09 08:23:06       3.40            100G
#
#         state                           city       tid
# 0         NSW                          TEMPE  29742568
# 1         NSW                          TEMPE  29742569
# 2         NSW                          TEMPE  29742570
# 3         NSW                          TEMPE  29742571
# 4         NSW                          TEMPE  29742572
# ...       ...                            ...       ...
# 488635    ACT  CANBERRA CIVIC DOORDASH DUMMY  30231203
# 488636    ACT  CANBERRA CIVIC DOORDASH DUMMY  30231204
# 488637    ACT  CANBERRA CIVIC DOORDASH DUMMY  30231205
# 488638    ACT  CANBERRA CIVIC DOORDASH DUMMY  30231206
# 488639    ACT  CANBERRA CIVIC DOORDASH DUMMY  30231207
#
# [488640 rows x 22 columns]
